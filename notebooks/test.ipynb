# %%
import pandas as pd

# %%
df = pd.read_csv("../output/test_cases/Single male_ full-time permane_20260131_131044_FIXED.csv")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 100)  # Adjust for XPath column
df
# Out:
#      Unnamed: 0                Group                            Element  \
# 0             0         Contact Info                          firstName
# 1             1         Contact Info                          firstName
# 2             2         Contact Info                              email
# 3             3         Contact Info                              email
# 4             4         Contact Info                         middleName
# 5             5         Contact Info                         middleName
# 6             6         Contact Info                       mobileNumber
# 7             7         Contact Info                       mobileNumber
# 8             8         Contact Info                           lastName
# 9             9         Contact Info                           lastName
# 10           10         Contact Info                      Select Branch
# 11           11         Contact Info      100 - TECU - MARABELLA BRANCH
# ...

# %%
# scenario 2

df2 = pd.read_csv("../output/test_cases/Single female_ self-employed_ _20260202_095635.csv")

# %%
df2
# Out:
#      Unnamed: 0                Group                                 Element  \
# 0             0         Contact Info                               firstName
# 1             1         Contact Info                               firstName
# 2             2         Contact Info                                   email
# 3             3         Contact Info                                   email
# 4             4         Contact Info                              middleName
# 5             5         Contact Info                              middleName
# 6             6         Contact Info                            mobileNumber
# 7             7         Contact Info                            mobileNumber
# 8             8         Contact Info                                lastName
# 9             9         Contact Info                                lastName
# 10           10         Contact Info                           Select Branch
# ...

# %%
# SCENARIO VALIDATION REPORT
# ======================================================================
# CSV File: generated/Single female_ self-employed_ _20260202_095635.csv
# Scenario: Single female, self-employed, 1 beneficiary, no joint partner, applying for LinC...
# ======================================================================

# Summary: 10 passed, 0 failed, 1 warnings

# ℹ️ INFO Row Count
#       Expected: 100-400 typical
#       Actual:   150
#       Details:  Total rows in generated CSV

# ✅ PASS Page Coverage
#       Expected: All 6 pages
#       Actual:   6/6 pages
#       Details:  All pages covered

# ✅ PASS Employment Status
#       Expected: SELF EMPLOYED
#       Actual:   SELF EMPLOYED

# ✅ PASS Marital Status
#       Expected: SINGLE
#       Actual:   SINGLE

# ✅ PASS Has Beneficiary
#       Expected: True
#       Actual:   True

# ⚠️ WARN Beneficiary Count
#       Expected: 1
#       Actual:   2

# ✅ PASS Has Joint Partner
#       Expected: False
#       Actual:   False

# ✅ PASS LinCU Card Application
#       Expected: True
#       Actual:   True

# ✅ PASS FIP Application
#       Expected: False
#       Actual:   False

# ✅ PASS All PEP Questions = No
#       Expected: All False
#       Actual:   All False

# ✅ PASS All FATCA Questions = No
#       Expected: All False
#       Actual:   All False

# ✅ PASS OTP Verifications
#       Expected: 2 (initial + final)
#       Actual:   4

# ======================================================================
# RESULT: ✅ VALIDATION PASSED
# ======================================================================
# (venv) impactoinfra@Prakyath schema %

# %%
# scenario3

df3 = pd.read_csv("../output/test_cases/Married male_ part-time employ_20260202_104905.csv")
df3
# Out:
#      Unnamed: 0                Group                                 Element  \
# 0             0         Contact Info                               firstName
# 1             1         Contact Info                               firstName
# 2             2         Contact Info                                   email
# 3             3         Contact Info                                   email
# 4             4         Contact Info                              middleName
# 5             5         Contact Info                              middleName
# 6             6         Contact Info                            mobileNumber
# 7             7         Contact Info                            mobileNumber
# 8             8         Contact Info                                lastName
# 9             9         Contact Info                                lastName
# 10           10         Contact Info                           Select Branch
# ...

# %%
# scenario 4

df4 = pd.read_csv("../output/test_cases/Married female_ full-time perm_20260202_112333.csv")
df4
# Out:
#      Unnamed: 0                Group                                 Element  \
# 0             0         Contact Info                               firstName
# 1             1         Contact Info                               firstName
# 2             2         Contact Info                                   email
# 3             3         Contact Info                                   email
# 4             4         Contact Info                              middleName
# 5             5         Contact Info                              middleName
# 6             6         Contact Info                            mobileNumber
# 7             7         Contact Info                            mobileNumber
# 8             8         Contact Info                                lastName
# 9             9         Contact Info                                lastName
# 10           10         Contact Info                           Select Branch
# ...

# %%
# ============================================================
# VALIDATION REPORT
# ============================================================
# Errors:   0
# Warnings: 1
# Info:     0
# ============================================================

# WARNINGS:
#   [WARNING] Row 0, Field 'fipPlan': Field 'fipPlan' may be required when 'isApplyingForFipApplication' is True

# (venv) impactoinfra@Prakyath test_case_generation % python3 src/validators/scenario_validator.py "output/test_cases/Married female_ full-time perm_20260202_112333.csv" "Married female, full-time permanent, 2 beneficiaries (brother 50%, daughter 50%), 1 joint partner (member ID 121668, spouse relation), applying for LinCU card, applying for FIP Plan A, all PEP/FATCA as No"



# ======================================================================
# SCENARIO VALIDATION REPORT
# ======================================================================
# CSV File: output/test_cases/Married female_ full-time perm_20260202_112333.csv
# Scenario: Married female, full-time permanent, 2 beneficiaries (brother 50%, daughter 50%)...
# ======================================================================

# Summary: 10 passed, 0 failed, 1 warnings

# ℹ️ INFO Row Count
#       Expected: 100-400 typical
#       Actual:   177
#       Details:  Total rows in generated CSV

# ✅ PASS Page Coverage
#       Expected: All 6 pages
#       Actual:   6/6 pages
#       Details:  All pages covered

# ✅ PASS Employment Status
#       Expected: FULL TIME PERMANENT
#       Actual:   FULL TIME PERMANENT

# ✅ PASS Marital Status
#       Expected: MARRIED
#       Actual:   MARRIED

# ✅ PASS Has Beneficiary
#       Expected: True
#       Actual:   True

# ⚠️ WARN Beneficiary Count
#       Expected: 2
#       Actual:   4

# ✅ PASS Has Joint Partner
#       Expected: True
#       Actual:   True

# ✅ PASS LinCU Card Application
#       Expected: True
#       Actual:   True

# ✅ PASS FIP Application
#       Expected: True
#       Actual:   True

# ✅ PASS All PEP Questions = No
#       Expected: All False
#       Actual:   All False

# ✅ PASS All FATCA Questions = No
#       Expected: All False
#       Actual:   All False

# ✅ PASS OTP Verifications
#       Expected: 2 (initial + final)
#       Actual:   4

# ======================================================================
# RESULT: ✅ VALIDATION PASSED
# ======================================================================
# (venv) impactoinfra@Prakyath test_case_generation %

# %%
# scenario 5
df5 = pd.read_csv("../output/test_cases/Single male_ unemployed_ no em_20260202_114444.csv")
df5
# Out:
#      Unnamed: 0                Group                                 Element  \
# 0             0         Contact Info                               firstName
# 1             1         Contact Info                               firstName
# 2             2         Contact Info                                   email
# 3             3         Contact Info                                   email
# 4             4         Contact Info                              middleName
# 5             5         Contact Info                              middleName
# 6             6         Contact Info                            mobileNumber
# 7             7         Contact Info                            mobileNumber
# 8             8         Contact Info                                lastName
# 9             9         Contact Info                                lastName
# 10           10         Contact Info                           Select Branch
# ...

# %%
# ============================================================
# VALIDATION REPORT
# ============================================================
# Errors:   0
# Warnings: 1
# Info:     0
# ============================================================

# WARNINGS:
#   [WARNING] Row 6, Field 'Value': Input action with empty value


# ======================================================================
# SCENARIO VALIDATION REPORT
# ======================================================================
# CSV File: /Users/impactoinfra/test_case_generation/output/test_cases/Single male_ unemployed_ no em_20260202_114444.csv
# Scenario: Single male, unemployed, no employer fields, permanent address same as mailing, ...
# ======================================================================

# Summary: 8 passed, 0 failed, 0 warnings

# ℹ️ INFO Row Count
#       Expected: 100-400 typical
#       Actual:   133
#       Details:  Total rows in generated CSV

# ✅ PASS Page Coverage
#       Expected: All 6 pages
#       Actual:   6/6 pages
#       Details:  All pages covered

# ✅ PASS Employment Status
#       Expected: UNEMPLOYED
#       Actual:   UNEMPLOYED

# ✅ PASS Marital Status
#       Expected: SINGLE
#       Actual:   SINGLE

# ✅ PASS Has Beneficiary
#       Expected: False
#       Actual:   False

# ✅ PASS Has Joint Partner
#       Expected: False
#       Actual:   False

# ✅ PASS LinCU Card Application
#       Expected: False
#       Actual:   False

# ✅ PASS FIP Application
#       Expected: False
#       Actual:   False

# ✅ PASS OTP Verifications
#       Expected: 2 (initial + final)
#       Actual:   4

# ======================================================================
# RESULT: ✅ VALIDATION PASSED
# ======================================================================
# (venv) impactoinfra@Prakyath test_case_generation %
